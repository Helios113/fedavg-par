# %%
import torch

# %%
a = torch.load("T4/t1/fed_ll_sig/paramsLoc0.mp")

# %%
print(a)
# Out:
# OrderedDict([('acc1.weight_ih_l0', tensor([[-0.0112,  0.1253, -0.0973],
#         [ 0.6522,  0.0833, -0.1694],
#         [ 0.0328,  0.0146,  0.2636],
#         [-0.0540, -0.0983, -0.2852],
#         [ 0.0505, -0.1804, -0.1261],
#         [ 0.0756, -0.0218, -0.1251],
#         [ 0.1485, -0.1548, -0.1005],
#         [ 0.0739, -0.2452,  0.3022],
#         [-0.2232, -0.0932,  0.2981],
#         [ 0.3858, -0.1922,  0.1118],
#         [ 0.3108, -0.0414,  0.0364],
#         [ 0.2122, -0.0259,  0.0217],
#         [ 0.2609,  0.1569, -0.4638],
#         [ 0.4746,  0.0426, -0.0229],
#         [ 0.3495, -0.4940, -0.0357],
#         [ 0.2058, -0.2571, -0.3868],
#         [ 0.2679, -0.1259,  0.0554],
#         [-0.0039, -0.2367,  0.1289],
#         [ 0.4966, -0.0733,  0.0032],
#         [-0.1279,  0.0303,  0.1794],
#         [-0.0812, -0.2683,  0.3763],
#         [-0.0985,  0.0076, -0.0867],
#         [ 0.1147, -0.1336,  0.2005],
#         [ 0.0684, -0.0195, -0.0519],
# ...
